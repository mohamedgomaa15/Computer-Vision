# %%
import random

# %%
import os

API_KEY = "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"

os.environ["WANDB_API_KEY"] = API_KEY
import wandb
wandb.login()
wandb.setup(settings=wandb.Settings(api_key=API_KEY))

run = wandb.init(project="my-first-project")
# Out:
# wandb: ERROR Error while calling W&B API: api key too short (<Response [401]>)
# wandb: WARNING [wandb.setup()] Changing session credentials to explicit value for https://api.wandb.ai.
# wandb: Currently logged in as: mohamed-gomaa6 (mohamed-gomaa6-student-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>d:\courses\computervision\computerVision\wandb\run-20260506_155328-zniyeaji</code>
# ...

# %%
# Simulate training.
epochs = 10
offset = random.random() / 5
for epoch in range(2, epochs):
    acc = 1 - 2**-epoch - random.random() / epoch - offset
    loss = 2**-epoch + random.random() / epoch + offset
    wandb.log({"acc": acc, "loss": loss})

# Finish the run and upload any remaining data.
run.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▄▇▆█▇▇█</td></tr><tr><td>loss</td><td>█▇▃▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.79409</td></tr><tr><td>loss</td><td>0.25994</td></tr></table><br/></div></div>
# ...

# %%
run = wandb.init(project="my-first-project")
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Finishing previous runs because reinit is set to 'default'.
# ...
